# %% [markdown]
# # **Primitive Data Types**

# %% [markdown]
# ## **Integer**

# %%
x = 150
y = 30

print(x)
# Out:
# 150

# %%
x = 150
y = 30

print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# ##**Float**

# %%
x = 1.10
y = 1.0
z = -35.59

print(type(z))
print(z)
# Out:
# <class 'float'>
# -35.59

# %% [markdown]
# ## **Complex**

# %%
z = 3 + 4j
print(z)
print(z.real)
print(z.imag)
# Out:
# (3+4j)
# 3.0
# 4.0

# %% [markdown]
# ## **String**

# %%
a = "Hello world"

print(a)
print(type(a))
# Out:
# Hello world
# <class 'str'>

# %% [markdown]
# ## **Boolean**

# %%
a = True
b = False
print(a)
print(b)
# Out:
# True
# False

# %% [markdown]
# # Non-Primitive Data Types

# %% [markdown]
# ## **List**

# %% [markdown]
# Membuat List

# %%
huruf = ["a", "b", "c", "d", "e", "f"]

print(huruf[1:4])
# Out:
# ['b', 'c', 'd']

# %%
numbers = [1, 2, 3, 4, 5]

mixed = [10, "Python", 3.14, True]

print(numbers)
print(mixed)
# Out:
# [1, 2, 3, 4, 5]
# [10, 'Python', 3.14, True]

# %% [markdown]
# Mnegakses Elemen List

# %%
fruits = ["Apple", "Banana", "Cherry"]

print(fruits[0])
print(fruits[1])
print(fruits[-1])
# Out:
# Apple
# Banana
# Cherry

# %% [markdown]
# Mengubah Elemen List

# %%
fruits[1] = "Mango"
print(fruits)
# Out:
# ['Apple', 'Mango', 'Cherry']

# %% [markdown]
# Menambahkan Elemen ke List

# %%
fruits.append("Orange")
print(fruits)

fruits.insert(1, "Grapes")
print(fruits)
# Out:
# ['Apple', 'Mango', 'Cherry', 'Orange']
# ['Apple', 'Grapes', 'Mango', 'Cherry', 'Orange']

# %% [markdown]
# Menghapus Elemen List

# %%
fruits.remove("Mango")
print(fruits)

fruits.pop(2)
print(fruits)

del fruits[1]
print(fruits)
# Out:
# ['Apple', 'Grapes', 'Cherry', 'Orange']
# ['Apple', 'Grapes', 'Orange']
# ['Apple', 'Orange']

# %% [markdown]
# Menggunakan Loop pada List

# %%
for fruit in fruits:
    print(fruit)
# Out:
# Apple
# Orange

# %% [markdown]
# Kesimpulan:
#
# 1. List menyimpan banyak nilai dalam satu variabel
# 2. Bisa diakses, diubah, ditambah, dan dihapus
# 3. Loop dan List Comprehension membuatnya lebih fleksibel

# %% [markdown]
# ## **Tuple**

# %%
numbers = (1, 2, 3, 4, 5)

mixed = (10, "Python", 3.14, True)

print(numbers)
print(mixed)
# Out:
# (1, 2, 3, 4, 5)
# (10, 'Python', 3.14, True)

# %% [markdown]
# Jika hanya satu elemen dalam tuple, tambahkan koma , agar Python mengenali sebagai tuple.

# %%
single_element = (5,)
not_tuple = (5)

print(type(single_element))
print(type(not_tuple))
# Out:
# <class 'tuple'>
# <class 'int'>

# %% [markdown]
# Mengakses Elemen Tuple

# %%
fruits = ("Apple", "Banana", "Cherry")

print(fruits[0])
print(fruits[-1])
# Out:
# Apple
# Cherry

# %% [markdown]
# Tuple tidak bisa diubah jika sudah dibuat, contoh:

# %% [markdown]
# tidak seperti list yang bisa diubah

# %%
# Membuat list buah
fruits = ["Apple", "Banana", "Cherry"]

print("Sebelum diubah:", fruits)

# Mengubah elemen kedua (indeks 1) menjadi "Mango"
fruits[1] = "Mango"

print("Sesudah diubah:", fruits)
# Out:
# Sebelum diubah: ['Apple', 'Banana', 'Cherry']
# Sesudah diubah: ['Apple', 'Mango', 'Cherry']

# %% [markdown]
#  Bisa Menyimpan Banyak Nilai Sekaligus (Packing & Unpacking)

# %%
data = ("Ezha", 21, "Data Scientist")

name, age, job = data

print(name)
print(age)
print(job)
# Out:
# Ezha
# 21
# Data Scientist

# %% [markdown]
# Menggabungkan Tuple

# %%
tuple1 = (1, 2, 3)
tuple2 = (4, 5, 6)

new_tuple = tuple1 + tuple2
print(new_tuple)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# Menghitung Elemen dalam Tuple

# %%
numbers = (1, 2, 2, 3, 4, 2, 5)

print(numbers.count(2))
print(numbers.index(5))
# Out:
# 3
# 6

# %% [markdown]
# Kesimpulan:
#
# 1. Tuple mirip list, tetapi immutable (tidak bisa diubah).
# 2. Lebih cepat dan aman dibanding list jika datanya tetap.
# 3. Bisa digunakan untuk menyimpan data yang tidak boleh berubah.

# %% [markdown]
# ### Hands On

# %%
lokasi = (12.5, -7.8, 100.2)

print("Koordinat awal:", lokasi)
# Out:
# Koordinat awal: (12.5, -7.8, 100.2)

# %%
lokasi = [0.0, 1.0, 2.0]   # list dengan 3 elemen
print("Sebelum diubah:", lokasi)

lokasi[0] = 15.0           # mengubah elemen pertama (indeks 0)
print("Sesudah diubah:", lokasi)
# Out:
# Sebelum diubah: [0.0, 1.0, 2.0]
# Sesudah diubah: [15.0, 1.0, 2.0]

# %% [markdown]
# ## **Dictionary**

# %% [markdown]
# Membuat Dictionary

# %%
student = {
    "nama": "Ali Muhsin",
    "umur": 21,
    "jurusan": "Artificial Intelligence"
}

print(student)
# Out:
# {'nama': 'Ali Muhsin', 'umur': 21, 'jurusan': 'Artificial Intelligence'}

# %% [markdown]
# Dictionary menggunakan kurung kurawal {}.

# %% [markdown]
# Mengakses Nilai dalam Dictionary

# %%
print(student["nama"])
print(student["umur"])
# Out:
# Ali Muhsin
# 21

# %% [markdown]
# Menambahkan atau Mengubah Data dalam Dictionary

# %%
student["alamat"] = "Yogyakarta"

student["umur"] = 25

print(student)
# Out:
# {'nama': 'Ali Muhsin', 'umur': 25, 'jurusan': 'Artificial Intelligence', 'alamat': 'Yogyakarta'}

# %% [markdown]
# menghapus elemen dalam dictionary

# %%
del student["jurusan"]

umur = student.pop("umur")

print(student)
print(umur)
# Out:
# {'nama': 'Ali Muhsin', 'alamat': 'Yogyakarta'}
# 25

# %% [markdown]
# Fungsi pop() pada dictionary digunakan untuk menghapus sebuah key dan mengembalikan nilai (value) yang dihapus.
# sedangkan "del" hanya menghapus tanpa menyimpan nilai

# %% [markdown]
# ## **Set**

# %%
angka = {1, 2, 3, 2, 4, 5}

huruf = {"a", "b", "c", "d"}

campuran = {1, "Python", 3.14}

print(angka)
print(huruf)
print(campuran)
# Out:
# {1, 2, 3, 4, 5}
# {'a', 'b', 'c', 'd'}
# {1, 3.14, 'Python'}

# %% [markdown]
# Ciri-ciri set:
# 1. Tidak ada elemen yang duplikat
# 2. Tidak memiliki indeks (tidak bisa diakses dengan angka index seperti list)

# %% [markdown]
# Menghapus Duplikat dari List dengan Set

# %%
angka_list = [1, 2, 2, 3, 4, 4, 5]
angka_set = set(angka_list)

print(angka_set)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# Menambah dan Menghapus Elemen Menggunakan Set

# %%
angka.add(6)
angka.remove(3)
print(angka)
# Out:
# {1, 2, 4, 5, 6}

# %% [markdown]
# **Operasi Himpunan (set operations)**
# Irisan (Intersection)

# %%
a = {1, 2, 3, 4}
b = {3, 4, 5, 6}

print(a & b)
# Out:
# {3, 4}

# %% [markdown]
# Gabungan atau Union

# %%
print(a | b)
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
#  Selisih (Difference)

# %%
print(a - b)
print(b - a)
# Out:
# {1, 2}
# {5, 6}

# %% [markdown]
# Kesimpulan
# 1. set digunakan untuk menyimpan elemen unik
# 2. Tidak memiliki indeks atau urutan tetap
# 3. Cocok untuk operasi himpunan (union, intersection, dll.)
# 4. Berguna untuk menghapus duplikat dari list

# %%
id_pengguna = {101, 202, 303, 404}

print("Sebelum ditambah:", id_pengguna)
# Out:
# Sebelum ditambah: {202, 404, 101, 303}

# %% [markdown]
# ### Hands On
#
# Jika saya ingin menambahkan
# 1. id_pengguna.add(505) dan
# 2. id_pengguna.add(101)
# apa yang terjadi?

# %%
id_pengguna.add(505)
print("Setelah ditambah:", id_pengguna)
# Out:
# Setelah ditambah: {101, 202, 303, 404, 505}

# %%
id_pengguna.add(101)
print("Setelah ditambah:", id_pengguna)
# Out:
# Setelah ditambah: {101, 202, 303, 404, 505}

# %% [markdown]
# # Konversi Tipe Data

# %% [markdown]
# Konversi Otomatis (Implicit Conversion)

# %%
angka_int = 10
angka_float = angka_int + 3.5

print(angka_float)
print(type(angka_float))
# Out:
# 13.5
# <class 'float'>

# %% [markdown]
# Python mengubah 10 (int) menjadi 10.0 (float) agar sesuai dengan operasi float.

# %% [markdown]
# Konversi Manual (Explicit Conversion)

# %% [markdown]
# int ke float / float ke int

# %%
x = 5
x_float = float(x)

y = 7.8
y_int = int(y)

print(x_float)
print(y_int)
# Out:
# 5.0
# 7

# %% [markdown]
# int/float ke string

# %%
angka = 42
angka_str = str(angka)

teks = "100"
teks_int = int(teks)

print(angka_str, type(angka_str))
print(teks_int, type(teks_int))
# Out:
# 42 <class 'str'>
# 100 <class 'int'>

# %% [markdown]
# list ke tuple

# %%
data_list = [1, 2, 3]
data_tuple = tuple(data_list)
data_tuple2 = (4, 5, 6)
data_list2 = list(data_tuple2)

print(data_tuple, type(data_tuple))
print(data_list2, type(data_list2))
# Out:
# (1, 2, 3) <class 'tuple'>
# [4, 5, 6] <class 'list'>

# %% [markdown]
# list/tuple ke set

# %%
angka_list = [1, 2, 2, 3]
angka_set = set(angka_list)

angka_tuple = tuple(angka_set)

print(angka_set)
print(angka_tuple)
# Out:
# {1, 2, 3}
# (1, 2, 3)

# %% [markdown]
# Dictionary ke Lis

# %%
data_dict = {"nama": "Abriel", "umur": 25}

keys_list = list(data_dict.keys())

values_list = list(data_dict.values())

print(keys_list)
print(values_list)
# Out:
# ['nama', 'umur']
# ['Abriel', 25]

# %% [markdown]
# Kesimpulan:
#
# 1. Konversi Otomatis terjadi saat Python perlu menyamakan tipe data dalam operasi.
# 2. Konversi Manual (Casting) dilakukan dengan fungsi bawaan (int(), float(), str(), list(), dll.).
# 3. Gunakan konversi yang tepat sesuai kebutuhan, terutama untuk menghindari error saat operasi antar tipe data.
